# %%
pip install ultralytics
# Out:
# Collecting ultralytics
#   Using cached ultralytics-8.2.16-py3-none-any.whl.metadata (40 kB)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\omkar\anaconda3\lib\site-packages (from ultralytics) (3.8.0)
# Requirement already satisfied: opencv-python>=4.6.0 in c:\users\omkar\anaconda3\lib\site-packages (from ultralytics) (4.9.0.80)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\omkar\anaconda3\lib\site-packages (from ultralytics) (10.2.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\omkar\anaconda3\lib\site-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in c:\users\omkar\anaconda3\lib\site-packages (from ultralytics) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\omkar\anaconda3\lib\site-packages (from ultralytics) (1.11.4)
# Requirement already satisfied: torch>=1.8.0 in c:\users\omkar\anaconda3\lib\site-packages (from ultralytics) (2.3.0)
# Collecting torchvision>=0.9.0 (from ultralytics)
#   Using cached torchvision-0.18.0-cp311-cp311-win_amd64.whl.metadata (6.6 kB)
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\omkar\anaconda3\lib\site-packages (from ultralytics) (4.65.0)
# Requirement already satisfied: psutil in c:\users\omkar\anaconda3\lib\site-packages (from ultralytics) (5.9.0)
# Requirement already satisfied: py-cpuinfo in c:\users\omkar\anaconda3\lib\site-packages (from ultralytics) (9.0.0)
# Collecting thop>=0.1.1 (from ultralytics)
#   Using cached thop-0.1.1.post2209072238-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\omkar\anaconda3\lib\site-packages (from ultralytics) (2.1.4)
# Requirement already satisfied: seaborn>=0.11.0 in c:\users\omkar\anaconda3\lib\site-packages (from ultralytics) (0.12.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\omkar\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\omkar\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\omkar\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\omkar\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.4)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\omkar\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\omkar\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\omkar\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\omkar\anaconda3\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\omkar\anaconda3\lib\site-packages (from pandas>=1.1.4->ultralytics) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\omkar\anaconda3\lib\site-packages (from pandas>=1.1.4->ultralytics) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\omkar\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\omkar\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\omkar\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\omkar\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (2024.2.2)
# Requirement already satisfied: filelock in c:\users\omkar\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\omkar\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (4.9.0)
# Requirement already satisfied: sympy in c:\users\omkar\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (1.12)
# Requirement already satisfied: networkx in c:\users\omkar\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1)
# Requirement already satisfied: jinja2 in c:\users\omkar\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.3)
# Requirement already satisfied: fsspec in c:\users\omkar\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (2023.10.0)
# Requirement already satisfied: mkl<=2021.4.0,>=2021.1.1 in c:\users\omkar\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (2021.4.0)
# Requirement already satisfied: colorama in c:\users\omkar\anaconda3\lib\site-packages (from tqdm>=4.64.0->ultralytics) (0.4.6)
# Requirement already satisfied: intel-openmp==2021.* in c:\users\omkar\anaconda3\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch>=1.8.0->ultralytics) (2021.4.0)
# Requirement already satisfied: tbb==2021.* in c:\users\omkar\anaconda3\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch>=1.8.0->ultralytics) (2021.12.0)
# Requirement already satisfied: six>=1.5 in c:\users\omkar\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\omkar\anaconda3\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in c:\users\omkar\anaconda3\lib\site-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)
# Using cached ultralytics-8.2.16-py3-none-any.whl (756 kB)
# Using cached thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Using cached torchvision-0.18.0-cp311-cp311-win_amd64.whl (1.2 MB)
# Installing collected packages: torchvision, thop, ultralytics
# Successfully installed thop-0.1.1.post2209072238 torchvision-0.18.0 ultralytics-8.2.16
# Note: you may need to restart the kernel to use updated packages.

# %%
from ultralytics import YOLO

# %%
from ultralytics import YOLO
import cv2
import math 
# start webcam
cap = cv2.VideoCapture(0)
cap.set(3, 640)
cap.set(4, 480)

# model
model = YOLO("yolo-Weights/yolov8n.pt")

# object classes
classNames = ["person", "bicycle", "car", "motorbike", "aeroplane", "bus", "train", "truck", "boat",
              "traffic light", "fire hydrant", "stop sign", "parking meter", "bench", "bird", "cat",
              "dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe", "backpack", "umbrella",
              "handbag", "tie", "suitcase", "frisbee", "skis", "snowboard", "sports ball", "kite", "baseball bat",
              "baseball glove", "skateboard", "surfboard", "tennis racket", "bottle", "wine glass", "cup",
              "fork", "knife", "spoon", "bowl", "banana", "apple", "sandwich", "orange", "broccoli",
              "carrot", "hot dog", "pizza", "donut", "cake", "chair", "sofa", "pottedplant", "bed",
              "diningtable", "toilet", "tvmonitor", "laptop", "mouse", "remote", "keyboard", "cell phone",
              "microwave", "oven", "toaster", "sink", "refrigerator", "book", "clock", "vase", "scissors",
              "teddy bear", "hair drier", "toothbrush"
              ]


while True:
    success, img = cap.read()
    results = model(img, stream=True)

    # coordinates
    for r in results:
        boxes = r.boxes

        for box in boxes:
            # bounding box
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2) # convert to int values

            # put box in cam
            cv2.rectangle(img, (x1, y1), (x2, y2), (255, 0, 255), 3)

            # confidence
            confidence = math.ceil((box.conf[0]*100))/100
            print("Confidence --->",confidence)

            # class name
            cls = int(box.cls[0])
            print("Class name -->", classNames[cls])

            # object details
            org = [x1, y1]
            font = cv2.FONT_HERSHEY_SIMPLEX
            fontScale = 1
            color = (255, 0, 0)
            thickness = 2

            cv2.putText(img, classNames[cls], org, font, fontScale, color, thickness)

    cv2.imshow('Webcam', img)
    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 person, 205.1ms
# Confidence ---> 0.81
# Class name --> person
# Speed: 8.0ms preprocess, 205.1ms inference, 1460.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 180.0ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.62
# Class name --> person
# Speed: 23.0ms preprocess, 180.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 109.9ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 0.7ms preprocess, 109.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 123.4ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.32
# Class name --> person
# Confidence ---> 0.3
# Class name --> laptop
# Speed: 2.0ms preprocess, 123.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 129.8ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.29
# Class name --> person
# Speed: 2.3ms preprocess, 129.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 116.8ms
# Confidence ---> 0.88
# Class name --> person
# Speed: 2.7ms preprocess, 116.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 113.1ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.59
# Class name --> person
# Speed: 3.4ms preprocess, 113.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 113.5ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.55
# Class name --> person
# Confidence ---> 0.28
# Class name --> person
# Speed: 2.8ms preprocess, 113.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 115.5ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.61
# Class name --> person
# Speed: 1.6ms preprocess, 115.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 135.2ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.65
# Class name --> person
# Speed: 0.0ms preprocess, 135.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 116.6ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.31
# Class name --> laptop
# Speed: 2.1ms preprocess, 116.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 117.2ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.74
# Class name --> person
# Speed: 3.2ms preprocess, 117.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 135.3ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.77
# Class name --> person
# Speed: 1.9ms preprocess, 135.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 122.7ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.75
# Class name --> person
# Speed: 4.5ms preprocess, 122.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 126.6ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.74
# Class name --> person
# Speed: 1.0ms preprocess, 126.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 135.1ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.74
# Class name --> person
# Speed: 1.7ms preprocess, 135.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 136.3ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.75
# Class name --> person
# Speed: 2.5ms preprocess, 136.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 116.1ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.74
# Class name --> person
# Speed: 0.6ms preprocess, 116.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 129.8ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.76
# Class name --> person
# Speed: 0.0ms preprocess, 129.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 159.1ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.77
# Class name --> person
# Speed: 3.4ms preprocess, 159.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 202.3ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.73
# Class name --> person
# Speed: 4.6ms preprocess, 202.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 304.4ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.74
# Class name --> person
# Speed: 8.6ms preprocess, 304.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 176.5ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.63
# Class name --> person
# Speed: 3.6ms preprocess, 176.5ms inference, 7.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 157.2ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.66
# Class name --> person
# Speed: 1.5ms preprocess, 157.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 160.2ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.67
# Class name --> person
# Speed: 1.5ms preprocess, 160.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 171.1ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.63
# Class name --> person
# Speed: 1.9ms preprocess, 171.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 222.6ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.63
# Class name --> person
# Speed: 0.0ms preprocess, 222.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 195.7ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.61
# Class name --> person
# Speed: 2.0ms preprocess, 195.7ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 149.7ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.62
# Class name --> person
# Speed: 4.6ms preprocess, 149.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 158.0ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.55
# Class name --> person
# Confidence ---> 0.41
# Class name --> cell phone
# Speed: 0.0ms preprocess, 158.0ms inference, 16.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 181.5ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.51
# Class name --> person
# Speed: 0.0ms preprocess, 181.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 164.9ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.64
# Class name --> cell phone
# Confidence ---> 0.58
# Class name --> person
# Speed: 4.6ms preprocess, 164.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 223.0ms
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.55
# Class name --> laptop
# Confidence ---> 0.27
# Class name --> person
# Speed: 3.0ms preprocess, 223.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 186.3ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.67
# Class name --> laptop
# Speed: 3.3ms preprocess, 186.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 156.2ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.7
# Class name --> laptop
# Speed: 3.1ms preprocess, 156.2ms inference, 15.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 151.4ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.55
# Class name --> laptop
# Speed: 3.1ms preprocess, 151.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 167.0ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.67
# Class name --> laptop
# Speed: 2.7ms preprocess, 167.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 143.7ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.79
# Class name --> laptop
# Speed: 2.1ms preprocess, 143.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 159.7ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.78
# Class name --> laptop
# Speed: 3.1ms preprocess, 159.7ms inference, 15.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 178.8ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.76
# Class name --> laptop
# Speed: 3.9ms preprocess, 178.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 151.0ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.74
# Class name --> laptop
# Speed: 3.0ms preprocess, 151.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 143.8ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.77
# Class name --> laptop
# Speed: 3.9ms preprocess, 143.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 160.6ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.53
# Class name --> laptop
# Speed: 3.7ms preprocess, 160.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 146.3ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.49
# Class name --> laptop
# Speed: 3.2ms preprocess, 146.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 158.8ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.39
# Class name --> person
# Confidence ---> 0.28
# Class name --> laptop
# Speed: 3.7ms preprocess, 158.8ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 tv, 154.2ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.54
# Class name --> person
# Confidence ---> 0.28
# Class name --> tvmonitor
# Speed: 2.2ms preprocess, 154.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 158.1ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.32
# Class name --> person
# Speed: 2.8ms preprocess, 158.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 190.8ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.75
# Class name --> laptop
# Confidence ---> 0.27
# Class name --> person
# Speed: 2.7ms preprocess, 190.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 176.7ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.82
# Class name --> laptop
# Speed: 3.0ms preprocess, 176.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 142.3ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.81
# Class name --> laptop
# Speed: 3.5ms preprocess, 142.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 160.2ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.81
# Class name --> laptop
# Speed: 3.0ms preprocess, 160.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 208.8ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.73
# Class name --> laptop
# Speed: 3.0ms preprocess, 208.8ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 143.1ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.77
# Class name --> laptop
# Speed: 3.7ms preprocess, 143.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 142.2ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.7
# Class name --> laptop
# Speed: 2.0ms preprocess, 142.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 133.3ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.78
# Class name --> laptop
# Speed: 2.0ms preprocess, 133.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 125.2ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.61
# Class name --> laptop
# Confidence ---> 0.37
# Class name --> person
# Speed: 2.0ms preprocess, 125.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 167.9ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.38
# Class name --> laptop
# Confidence ---> 0.28
# Class name --> person
# Speed: 2.0ms preprocess, 167.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 156.7ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.31
# Class name --> person
# Confidence ---> 0.28
# Class name --> cell phone
# Speed: 3.0ms preprocess, 156.7ms inference, 6.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 131.0ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.62
# Class name --> person
# Speed: 2.4ms preprocess, 131.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 127.7ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.65
# Class name --> person
# Speed: 2.0ms preprocess, 127.7ms inference, 11.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 151.8ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.68
# Class name --> person
# Speed: 2.0ms preprocess, 151.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 162.8ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.7
# Class name --> person
# Speed: 2.9ms preprocess, 162.8ms inference, 5.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 179.4ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.26
# Class name --> cell phone
# Speed: 2.0ms preprocess, 179.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 155.2ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.65
# Class name --> person
# Speed: 2.4ms preprocess, 155.2ms inference, 15.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 141.3ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.28
# Class name --> cell phone
# Speed: 2.6ms preprocess, 141.3ms inference, 15.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 135.6ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.66
# Class name --> person
# Confidence ---> 0.29
# Class name --> cell phone
# Speed: 2.0ms preprocess, 135.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 143.2ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.64
# Class name --> person
# Speed: 2.5ms preprocess, 143.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 131.9ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.61
# Class name --> person
# Confidence ---> 0.32
# Class name --> cell phone
# Speed: 2.0ms preprocess, 131.9ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 166.9ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.59
# Class name --> person
# Speed: 3.5ms preprocess, 166.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 155.8ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.48
# Class name --> person
# Speed: 2.0ms preprocess, 155.8ms inference, 15.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 146.5ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.54
# Class name --> person
# Confidence ---> 0.26
# Class name --> cell phone
# Speed: 3.0ms preprocess, 146.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 146.5ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.53
# Class name --> person
# Speed: 2.0ms preprocess, 146.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 139.5ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.58
# Class name --> person
# Confidence ---> 0.34
# Class name --> cell phone
# Speed: 3.0ms preprocess, 139.5ms inference, 15.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 167.4ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.62
# Class name --> person
# Speed: 3.0ms preprocess, 167.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 150.3ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.65
# Class name --> person
# Speed: 1.7ms preprocess, 150.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 129.8ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.56
# Class name --> person
# Speed: 2.0ms preprocess, 129.8ms inference, 14.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 135.7ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.64
# Class name --> person
# Speed: 2.0ms preprocess, 135.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 154.6ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.72
# Class name --> person
# Speed: 2.6ms preprocess, 154.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 141.7ms
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.62
# Class name --> person
# Confidence ---> 0.35
# Class name --> cell phone
# Speed: 2.9ms preprocess, 141.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 178.7ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.46
# Class name --> person
# Speed: 3.0ms preprocess, 178.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 142.9ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.74
# Class name --> person
# Speed: 3.6ms preprocess, 142.9ms inference, 15.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 136.8ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.71
# Class name --> person
# Speed: 2.0ms preprocess, 136.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 126.0ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.76
# Class name --> person
# Speed: 2.0ms preprocess, 126.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 148.2ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.75
# Class name --> person
# Speed: 2.0ms preprocess, 148.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 142.7ms
# Confidence ---> 0.44
# Class name --> person
# Confidence ---> 0.44
# Class name --> person
# Confidence ---> 0.41
# Class name --> person
# Confidence ---> 0.36
# Class name --> person
# Speed: 2.0ms preprocess, 142.7ms inference, 16.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 tv, 182.8ms
# Confidence ---> 0.51
# Class name --> person
# Confidence ---> 0.49
# Class name --> person
# Confidence ---> 0.36
# Class name --> tvmonitor
# Speed: 3.0ms preprocess, 182.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 148.9ms
# Confidence ---> 0.58
# Class name --> person
# Confidence ---> 0.55
# Class name --> person
# Speed: 3.2ms preprocess, 148.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 144.7ms
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.56
# Class name --> person
# Speed: 3.0ms preprocess, 144.7ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 tv, 134.8ms
# Confidence ---> 0.64
# Class name --> person
# Confidence ---> 0.42
# Class name --> person
# Confidence ---> 0.32
# Class name --> tvmonitor
# Speed: 2.5ms preprocess, 134.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 136.5ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.42
# Class name --> person
# Speed: 2.0ms preprocess, 136.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 141.2ms
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.78
# Class name --> person
# Speed: 0.0ms preprocess, 141.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 158.0ms
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.58
# Class name --> person
# Confidence ---> 0.46
# Class name --> laptop
# Speed: 2.0ms preprocess, 158.0ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 164.7ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.7
# Class name --> laptop
# Speed: 0.0ms preprocess, 164.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 153.7ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.74
# Class name --> laptop
# Speed: 3.0ms preprocess, 153.7ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 146.3ms
# Confidence ---> 0.8
# Class name --> laptop
# Confidence ---> 0.73
# Class name --> person
# Speed: 3.0ms preprocess, 146.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 129.5ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.78
# Class name --> laptop
# Speed: 2.0ms preprocess, 129.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 laptop, 123.3ms
# Confidence ---> 0.78
# Class name --> laptop
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.28
# Class name --> person
# Confidence ---> 0.28
# Class name --> person
# Speed: 2.0ms preprocess, 123.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 160.7ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.76
# Class name --> laptop
# Confidence ---> 0.3
# Class name --> person
# Speed: 2.5ms preprocess, 160.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 157.9ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.72
# Class name --> laptop
# Speed: 3.0ms preprocess, 157.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 148.7ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.81
# Class name --> laptop
# Speed: 4.5ms preprocess, 148.7ms inference, 15.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 cell phone, 148.2ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.62
# Class name --> laptop
# Confidence ---> 0.52
# Class name --> cell phone
# Speed: 2.2ms preprocess, 148.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 128.5ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.43
# Class name --> person
# Confidence ---> 0.4
# Class name --> person
# Confidence ---> 0.33
# Class name --> person
# Speed: 2.0ms preprocess, 128.5ms inference, 16.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 tv, 150.6ms
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.51
# Class name --> tvmonitor
# Confidence ---> 0.33
# Class name --> person
# Speed: 2.0ms preprocess, 150.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 164.2ms
# Confidence ---> 0.87
# Class name --> person
# Speed: 3.5ms preprocess, 164.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 toothbrush, 124.8ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.31
# Class name --> person
# Confidence ---> 0.26
# Class name --> toothbrush
# Speed: 3.0ms preprocess, 124.8ms inference, 15.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 125.7ms
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.48
# Class name --> person
# Speed: 2.0ms preprocess, 125.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 tv, 137.2ms
# Confidence ---> 0.62
# Class name --> person
# Confidence ---> 0.44
# Class name --> person
# Confidence ---> 0.4
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 137.2ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 1 tv, 133.6ms
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.46
# Class name --> tvmonitor
# Confidence ---> 0.41
# Class name --> person
# Confidence ---> 0.26
# Class name --> bottle
# Speed: 2.0ms preprocess, 133.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 tv, 144.7ms
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.43
# Class name --> tvmonitor
# Confidence ---> 0.31
# Class name --> person
# Confidence ---> 0.27
# Class name --> person
# Speed: 2.5ms preprocess, 144.7ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 tv, 200.6ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.36
# Class name --> tvmonitor
# Confidence ---> 0.27
# Class name --> person
# Speed: 2.0ms preprocess, 200.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 tv, 145.2ms
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.35
# Class name --> person
# Confidence ---> 0.29
# Class name --> tvmonitor
# Speed: 3.0ms preprocess, 145.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 132.1ms
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.34
# Class name --> person
# Confidence ---> 0.31
# Class name --> person
# Confidence ---> 0.27
# Class name --> person
# Speed: 2.5ms preprocess, 132.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 125.6ms
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.33
# Class name --> person
# Speed: 3.0ms preprocess, 125.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 144.4ms
# Confidence ---> 0.88
# Class name --> person
# Confidence ---> 0.26
# Class name --> person
# Speed: 3.0ms preprocess, 144.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 148.9ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.39
# Class name --> person
# Speed: 2.0ms preprocess, 148.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 162.9ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.36
# Class name --> person
# Confidence ---> 0.27
# Class name --> person
# Speed: 3.4ms preprocess, 162.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 145.6ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.37
# Class name --> person
# Confidence ---> 0.29
# Class name --> bottle
# Speed: 3.0ms preprocess, 145.6ms inference, 15.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 137.7ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.74
# Class name --> person
# Speed: 2.0ms preprocess, 137.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 tie, 1 cell phone, 152.1ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.46
# Class name --> tie
# Confidence ---> 0.32
# Class name --> cell phone
# Speed: 2.0ms preprocess, 152.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 tie, 1 cell phone, 128.5ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.37
# Class name --> person
# Confidence ---> 0.3
# Class name --> cell phone
# Confidence ---> 0.26
# Class name --> tie
# Speed: 2.0ms preprocess, 128.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 tie, 1 cell phone, 140.6ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.49
# Class name --> cell phone
# Confidence ---> 0.35
# Class name --> tie
# Speed: 2.0ms preprocess, 140.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 174.0ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.32
# Class name --> cell phone
# Speed: 4.0ms preprocess, 174.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 144.0ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.26
# Class name --> person
# Speed: 3.0ms preprocess, 144.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 142.0ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.6
# Class name --> person
# Confidence ---> 0.34
# Class name --> person
# Speed: 2.5ms preprocess, 142.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 139.8ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.79
# Class name --> person
# Speed: 2.0ms preprocess, 139.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 131.9ms
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.29
# Class name --> person
# Confidence ---> 0.27
# Class name --> person
# Speed: 2.3ms preprocess, 131.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 153.1ms
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.59
# Class name --> person
# Confidence ---> 0.36
# Class name --> person
# Speed: 2.0ms preprocess, 153.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 2 cell phones, 157.3ms
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.71
# Class name --> cell phone
# Confidence ---> 0.38
# Class name --> person
# Confidence ---> 0.27
# Class name --> cell phone
# Confidence ---> 0.26
# Class name --> bottle
# Speed: 3.0ms preprocess, 157.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 144.9ms
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.64
# Class name --> cell phone
# Confidence ---> 0.33
# Class name --> person
# Speed: 3.0ms preprocess, 144.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 130.6ms
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.4
# Class name --> bottle
# Speed: 2.0ms preprocess, 130.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 126.4ms
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.56
# Class name --> bottle
# Confidence ---> 0.38
# Class name --> person
# Speed: 2.0ms preprocess, 126.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 1 cell phone, 128.1ms
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.44
# Class name --> bottle
# Confidence ---> 0.43
# Class name --> person
# Confidence ---> 0.33
# Class name --> cell phone
# Speed: 2.0ms preprocess, 128.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 2 cell phones, 136.9ms
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.49
# Class name --> cell phone
# Confidence ---> 0.49
# Class name --> person
# Confidence ---> 0.28
# Class name --> cell phone
# Speed: 2.0ms preprocess, 136.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 129.4ms
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.62
# Class name --> cell phone
# Speed: 2.7ms preprocess, 129.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 cell phone, 142.5ms
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.47
# Class name --> person
# Confidence ---> 0.35
# Class name --> person
# Confidence ---> 0.29
# Class name --> cell phone
# Speed: 2.0ms preprocess, 142.5ms inference, 15.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 cell phone, 150.2ms
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.33
# Class name --> person
# Confidence ---> 0.3
# Class name --> person
# Confidence ---> 0.28
# Class name --> cell phone
# Speed: 3.0ms preprocess, 150.2ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 133.8ms
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.41
# Class name --> person
# Confidence ---> 0.28
# Class name --> cell phone
# Speed: 3.3ms preprocess, 133.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bottle, 2 cell phones, 159.8ms
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.3
# Class name --> cell phone
# Confidence ---> 0.29
# Class name --> person
# Confidence ---> 0.29
# Class name --> cell phone
# Confidence ---> 0.27
# Class name --> bottle
# Confidence ---> 0.26
# Class name --> person
# Speed: 2.0ms preprocess, 159.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 cell phone, 143.1ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.38
# Class name --> cell phone
# Confidence ---> 0.35
# Class name --> person
# Confidence ---> 0.26
# Class name --> person
# Speed: 2.0ms preprocess, 143.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 cell phone, 145.3ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.37
# Class name --> person
# Confidence ---> 0.33
# Class name --> cell phone
# Confidence ---> 0.29
# Class name --> person
# Speed: 3.0ms preprocess, 145.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 remote, 1 cell phone, 127.0ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.41
# Class name --> person
# Confidence ---> 0.37
# Class name --> remote
# Confidence ---> 0.34
# Class name --> cell phone
# Confidence ---> 0.26
# Class name --> person
# Speed: 3.0ms preprocess, 127.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 cell phone, 158.4ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.49
# Class name --> cell phone
# Confidence ---> 0.49
# Class name --> person
# Confidence ---> 0.36
# Class name --> person
# Speed: 2.0ms preprocess, 158.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 remote, 1 cell phone, 134.7ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.53
# Class name --> person
# Confidence ---> 0.42
# Class name --> cell phone
# Confidence ---> 0.27
# Class name --> remote
# Speed: 0.0ms preprocess, 134.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 tv, 1 cell phone, 129.3ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.55
# Class name --> person
# Confidence ---> 0.39
# Class name --> cell phone
# Confidence ---> 0.27
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 129.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 141.5ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.37
# Class name --> person
# Confidence ---> 0.31
# Class name --> cell phone
# Speed: 2.0ms preprocess, 141.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 176.5ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.52
# Class name --> person
# Confidence ---> 0.35
# Class name --> bottle
# Speed: 2.5ms preprocess, 176.5ms inference, 15.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 tv, 1 cell phone, 148.1ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.52
# Class name --> cell phone
# Confidence ---> 0.42
# Class name --> person
# Confidence ---> 0.26
# Class name --> tvmonitor
# Speed: 3.4ms preprocess, 148.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 139.4ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.59
# Class name --> person
# Confidence ---> 0.38
# Class name --> cell phone
# Speed: 2.2ms preprocess, 139.4ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 tv, 1 cell phone, 118.9ms
# Confidence ---> 0.85
# Class name --> person
# Confidence ---> 0.43
# Class name --> cell phone
# Confidence ---> 0.37
# Class name --> person
# Confidence ---> 0.26
# Class name --> tvmonitor
# Speed: 3.0ms preprocess, 118.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 139.5ms
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.44
# Class name --> person
# Confidence ---> 0.41
# Class name --> bottle
# Speed: 2.0ms preprocess, 139.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bottle, 1 tv, 142.5ms
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.42
# Class name --> person
# Confidence ---> 0.39
# Class name --> bottle
# Confidence ---> 0.32
# Class name --> tvmonitor
# Confidence ---> 0.3
# Class name --> person
# Speed: 2.0ms preprocess, 142.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 139.8ms
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.46
# Class name --> bottle
# Confidence ---> 0.39
# Class name --> person
# Speed: 2.3ms preprocess, 139.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 tv, 1 cell phone, 152.5ms
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.47
# Class name --> cell phone
# Confidence ---> 0.4
# Class name --> tvmonitor
# Confidence ---> 0.38
# Class name --> person
# Speed: 2.0ms preprocess, 152.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 tv, 1 cell phone, 140.4ms
# Confidence ---> 0.81
# Class name --> person
# Confidence ---> 0.74
# Class name --> cell phone
# Confidence ---> 0.45
# Class name --> person
# Confidence ---> 0.31
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 140.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 126.9ms
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.61
# Class name --> cell phone
# Confidence ---> 0.34
# Class name --> person
# Speed: 2.0ms preprocess, 126.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 tv, 1 cell phone, 126.2ms
# Confidence ---> 0.71
# Class name --> cell phone
# Confidence ---> 0.69
# Class name --> person
# Confidence ---> 0.36
# Class name --> person
# Confidence ---> 0.31
# Class name --> person
# Confidence ---> 0.28
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 126.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 tv, 1 cell phone, 140.6ms
# Confidence ---> 0.74
# Class name --> cell phone
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.49
# Class name --> person
# Confidence ---> 0.26
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 140.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 161.5ms
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.65
# Class name --> cell phone
# Confidence ---> 0.51
# Class name --> person
# Speed: 3.0ms preprocess, 161.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 156.5ms
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.49
# Class name --> person
# Confidence ---> 0.46
# Class name --> cell phone
# Speed: 2.5ms preprocess, 156.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 140.3ms
# Confidence ---> 0.83
# Class name --> person
# Confidence ---> 0.49
# Class name --> person
# Confidence ---> 0.34
# Class name --> cell phone
# Speed: 3.0ms preprocess, 140.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 127.3ms
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.46
# Class name --> person
# Confidence ---> 0.46
# Class name --> cell phone
# Speed: 2.0ms preprocess, 127.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 145.2ms
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.53
# Class name --> person
# Confidence ---> 0.47
# Class name --> cell phone
# Speed: 2.0ms preprocess, 145.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 133.5ms
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.49
# Class name --> person
# Confidence ---> 0.48
# Class name --> cell phone
# Speed: 3.1ms preprocess, 133.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 138.3ms
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.74
# Class name --> cell phone
# Confidence ---> 0.58
# Class name --> person
# Speed: 2.0ms preprocess, 138.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 153.8ms
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.55
# Class name --> person
# Confidence ---> 0.37
# Class name --> cell phone
# Speed: 2.0ms preprocess, 153.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 152.0ms
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.48
# Class name --> cell phone
# Confidence ---> 0.46
# Class name --> person
# Speed: 2.0ms preprocess, 152.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 138.4ms
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.43
# Class name --> person
# Confidence ---> 0.41
# Class name --> cell phone
# Speed: 2.0ms preprocess, 138.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 141.5ms
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.52
# Class name --> person
# Speed: 2.0ms preprocess, 141.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 131.0ms
# Confidence ---> 0.67
# Class name --> person
# Confidence ---> 0.61
# Class name --> cell phone
# Confidence ---> 0.38
# Class name --> person
# Speed: 2.7ms preprocess, 131.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 cell phone, 131.9ms
# Confidence ---> 0.65
# Class name --> person
# Confidence ---> 0.55
# Class name --> cell phone
# Confidence ---> 0.47
# Class name --> person
# Confidence ---> 0.34
# Class name --> person
# Speed: 2.0ms preprocess, 131.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 cell phone, 155.0ms
# Confidence ---> 0.8
# Class name --> cell phone
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.49
# Class name --> person
# Confidence ---> 0.43
# Class name --> person
# Speed: 2.0ms preprocess, 155.0ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 138.2ms
# Confidence ---> 0.78
# Class name --> cell phone
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.47
# Class name --> person
# Speed: 2.5ms preprocess, 138.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cell phone, 140.1ms
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.67
# Class name --> cell phone
# Confidence ---> 0.54
# Class name --> person
# Speed: 1.5ms preprocess, 140.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 bottle, 169.7ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.36
# Class name --> person
# Confidence ---> 0.31
# Class name --> bottle
# Speed: 2.1ms preprocess, 169.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 161.9ms
# Confidence ---> 0.79
# Class name --> person
# Speed: 3.0ms preprocess, 161.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 tv, 1 cell phone, 134.1ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.51
# Class name --> person
# Confidence ---> 0.49
# Class name --> tvmonitor
# Confidence ---> 0.29
# Class name --> cell phone
# Confidence ---> 0.28
# Class name --> person
# Confidence ---> 0.27
# Class name --> person
# Speed: 2.0ms preprocess, 134.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 tv, 148.3ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.5
# Class name --> person
# Confidence ---> 0.49
# Class name --> tvmonitor
# Speed: 3.0ms preprocess, 148.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 tv, 136.4ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.55
# Class name --> person
# Confidence ---> 0.45
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 136.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 130.0ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.36
# Class name --> laptop
# Confidence ---> 0.27
# Class name --> person
# Speed: 2.0ms preprocess, 130.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 1 cell phone, 171.0ms
# Confidence ---> 0.86
# Class name --> person
# Confidence ---> 0.55
# Class name --> laptop
# Confidence ---> 0.41
# Class name --> person
# Confidence ---> 0.31
# Class name --> cell phone
# Speed: 1.5ms preprocess, 171.0ms inference, 15.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 166.4ms
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.58
# Class name --> laptop
# Speed: 3.5ms preprocess, 166.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 130.4ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.69
# Class name --> laptop
# Confidence ---> 0.63
# Class name --> person
# Speed: 2.0ms preprocess, 130.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 145.4ms
# Confidence ---> 0.82
# Class name --> person
# Confidence ---> 0.7
# Class name --> person
# Speed: 2.0ms preprocess, 145.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 131.4ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.76
# Class name --> person
# Speed: 2.0ms preprocess, 131.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 tv, 129.2ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.34
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 129.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 tv, 150.0ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.8
# Class name --> person
# Confidence ---> 0.27
# Class name --> tvmonitor
# Speed: 1.5ms preprocess, 150.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 tv, 145.7ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.29
# Class name --> tvmonitor
# Speed: 3.0ms preprocess, 145.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 154.5ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.27
# Class name --> laptop
# Speed: 2.0ms preprocess, 154.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 tv, 158.8ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.77
# Class name --> person
# Confidence ---> 0.33
# Class name --> tvmonitor
# Speed: 3.0ms preprocess, 158.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 131.1ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.61
# Class name --> person
# Confidence ---> 0.5
# Class name --> laptop
# Speed: 3.3ms preprocess, 131.1ms inference, 9.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 129.9ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.71
# Class name --> laptop
# Confidence ---> 0.66
# Class name --> person
# Speed: 2.0ms preprocess, 129.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 146.5ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.61
# Class name --> laptop
# Speed: 2.0ms preprocess, 146.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 143.8ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.39
# Class name --> laptop
# Confidence ---> 0.3
# Class name --> person
# Speed: 3.3ms preprocess, 143.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 167.9ms
# Confidence ---> 0.9
# Class name --> person
# Speed: 2.0ms preprocess, 167.9ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 151.9ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.73
# Class name --> laptop
# Speed: 2.0ms preprocess, 151.9ms inference, 15.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 1 cell phone, 138.9ms
# Confidence ---> 0.87
# Class name --> person
# Confidence ---> 0.52
# Class name --> laptop
# Confidence ---> 0.46
# Class name --> person
# Confidence ---> 0.37
# Class name --> cell phone
# Speed: 0.0ms preprocess, 138.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 1 laptop, 127.7ms
# Confidence ---> 0.84
# Class name --> person
# Confidence ---> 0.6
# Class name --> laptop
# Confidence ---> 0.37
# Class name --> tvmonitor
# Speed: 2.0ms preprocess, 127.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 133.9ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.64
# Class name --> laptop
# Confidence ---> 0.48
# Class name --> person
# Speed: 2.8ms preprocess, 133.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 144.8ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.77
# Class name --> laptop
# Confidence ---> 0.35
# Class name --> person
# Speed: 2.0ms preprocess, 144.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 laptop, 160.6ms
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.77
# Class name --> laptop
# Confidence ---> 0.59
# Class name --> person
# Confidence ---> 0.55
# Class name --> person
# Speed: 3.0ms preprocess, 160.6ms inference, 11.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 laptop, 168.3ms
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.7
# Class name --> laptop
# Confidence ---> 0.53
# Class name --> person
# Confidence ---> 0.4
# Class name --> person
# Speed: 2.0ms preprocess, 168.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 laptop, 136.9ms
# Confidence ---> 0.72
# Class name --> laptop
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.47
# Class name --> person
# Confidence ---> 0.39
# Class name --> person
# Confidence ---> 0.28
# Class name --> person
# Speed: 2.5ms preprocess, 136.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 laptop, 139.7ms
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.77
# Class name --> laptop
# Confidence ---> 0.43
# Class name --> person
# Confidence ---> 0.37
# Class name --> person
# Speed: 2.0ms preprocess, 139.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 146.5ms
# Confidence ---> 0.89
# Class name --> person
# Confidence ---> 0.75
# Class name --> laptop
# Confidence ---> 0.73
# Class name --> person
# Speed: 2.5ms preprocess, 146.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 bottle, 1 laptop, 157.8ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.71
# Class name --> laptop
# Confidence ---> 0.53
# Class name --> person
# Confidence ---> 0.34
# Class name --> bottle
# Confidence ---> 0.27
# Class name --> person
# Speed: 2.6ms preprocess, 157.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 170.5ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.66
# Class name --> laptop
# Confidence ---> 0.57
# Class name --> person
# Speed: 3.0ms preprocess, 170.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 156.0ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.6
# Class name --> laptop
# Speed: 2.7ms preprocess, 156.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 133.2ms
# Confidence ---> 0.92
# Class name --> person
# Confidence ---> 0.68
# Class name --> laptop
# Confidence ---> 0.64
# Class name --> person
# Speed: 2.0ms preprocess, 133.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 128.0ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.62
# Class name --> laptop
# Confidence ---> 0.35
# Class name --> person
# Speed: 2.0ms preprocess, 128.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 laptop, 150.0ms
# Confidence ---> 0.93
# Class name --> person
# Confidence ---> 0.65
# Class name --> laptop
# Confidence ---> 0.38
# Class name --> person
# Speed: 2.7ms preprocess, 150.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 laptop, 1 cell phone, 153.0ms
# Confidence ---> 0.91
# Class name --> person
# Confidence ---> 0.61
# Class name --> laptop
# Confidence ---> 0.31
# Class name --> cell phone
# Speed: 2.0ms preprocess, 153.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 tv, 1 laptop, 158.1ms
# Confidence ---> 0.9
# Class name --> person
# Confidence ---> 0.8
# Class name --> laptop
# Confidence ---> 0.49
# Class name --> tvmonitor
# Speed: 3.0ms preprocess, 158.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)

# %%
python3 -m venv yolo
